# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade openai
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 42 kB 678 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 162 kB 8.2 MB/s
# ...
#   Created wheel for openai: filename=openai-0.18.1-py3-none-any.whl size=53168 sha256=68e2c8f2b7f656e7e77178b2b624c8bf2028adfe8e0497fd7113b12f6d28633a
#   Stored in directory: /root/.cache/pip/wheels/5a/bf/24/fcdc9d2b81f9c7e565bb2036ec9f7cc930056b829895b3bf48
# Successfully built openai
# ...
#      |████████████████████████████████| 1.8 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 145 kB 62.0 MB/s
# ...
#      |████████████████████████████████| 181 kB 41.4 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.5 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=a99ea5771a1ceab391ad3b72b4986e2257270cb869ab2f282a54db60df86282c
# ...

# %%
# !export OPENAI_API_KEY="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"
# %cd "/content/drive/MyDrive/DataEngineering/OpenAI Samples"
# %ls
# Out:
# /content/drive/MyDrive/DataEngineering/OpenAI Samples
# 'OpenAI_sample[Arts & Entertainment].json'  'OpenAI_sample[Food & Drink].json'

# %%
import json

data = None
with open("OpenAI_sample[Food & Drink].json", "r") as fh:
  data = json.load(fh)

len(data)

data_random = data[::10]
len(data_random)

with open("OpenAI_sample[Food & Drink]2.json", "w") as fh:
  json.dump(data_random, fh)

# %%
# !openai tools fine_tunes.prepare_data -f "OpenAI_sample[Food & Drink]2.json"
# Out:
# Analyzing...
#
# - Your file contains 1000 prompt-completion pairs
# - Your data does not contain a common separator at the end of your prompts. Having a separator string appended to the end of the prompt makes it clearer to the fine-tuned model where the completion should begin. See https://beta.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more detail and examples. If you intend to do open-ended generation, then you should leave the prompts empty
# - All prompts start with prefix `#`
# - All completions start with prefix `#Person`. Most of the time you should only add the output data into the completion, without any prefix
# - Your data does not contain a common ending at the end of your completions. Having a common ending string appended to the end of the completion makes it clearer to the fine-tuned model where the completion should end. See https://beta.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more detail and examples.
# ...

# %%
# !openai api fine_tunes.create -t "OpenAI_sample[Food & Drink]_prepared.jsonl"
# Out:
# Error: No API key provided. You can set your API key in code using 'openai.api_key = <API-KEY>', or you can set the environment variable OPENAI_API_KEY=<API-KEY>). If your API key is stored in a file, you can point the openai module at it with 'openai.api_key_path = <PATH>'. You can generate API keys in the OpenAI web interface. See https://onboard.openai.com for details, or email support@openai.com if you have any questions.

# %%
# !openai -k "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" api fine_tunes.create -t "OpenAI_sample[Food & Drink]2_prepared.jsonl"
# Out:
# Upload progress: 100% 601k/601k [00:00<00:00, 898Mit/s]
# Uploaded file from OpenAI_sample[Food & Drink]2_prepared.jsonl: file-Ne6m3GApxYrr0XyILwPjzaNC
# Created fine-tune: ft-Fi7Vci3L9RPg15MRreRGXHzC
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2022-03-08 20:53:04] Created fine-tune: ft-Fi7Vci3L9RPg15MRreRGXHzC
# [2022-03-08 20:53:16] Fine-tune costs $1.99
# [2022-03-08 20:53:16] Fine-tune enqueued. Queue number: 0
# [2022-03-08 20:53:20] Fine-tune started
# [2022-03-08 20:59:28] Completed epoch 1/4
#
# Stream interrupted (client disconnected).
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-Fi7Vci3L9RPg15MRreRGXHzC

# %%
# !openai -k "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" api fine_tunes.follow -i ft-Fi7Vci3L9RPg15MRreRGXHzC
# Out:
# [2022-03-08 20:53:04] Created fine-tune: ft-Fi7Vci3L9RPg15MRreRGXHzC
# [2022-03-08 20:53:16] Fine-tune costs $1.99
# [2022-03-08 20:53:16] Fine-tune enqueued. Queue number: 0
# [2022-03-08 20:53:20] Fine-tune started
# [2022-03-08 20:59:28] Completed epoch 1/4
# [2022-03-08 21:04:57] Completed epoch 2/4
# [2022-03-08 21:10:27] Completed epoch 3/4
# [2022-03-08 21:15:55] Completed epoch 4/4
# [2022-03-08 21:16:23] Uploaded model: curie:ft-personal-2022-03-08-21-16-22
# [2022-03-08 21:16:26] Uploaded result file: file-z2PxeOIuD9jy1Sd5icKYHjRz
# [2022-03-08 21:16:27] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m curie:ft-personal-2022-03-08-21-16-22 -p <YOUR_PROMPT>

# %%
import openai

OPENAI_API_KEY = "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"
openai.api_key = OPENAI_API_KEY

openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="Hi, how are you?",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jnej1fGAI8I0vjaL2vuTrxAbPKEI at 0x7f2d88256350> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " What was your first impression of the city?\n#0028fd1:"
#     }
#   ],
#   "created": 1646820985,
#   "id": "cmpl-4jnej1fGAI8I0vjaL2vuTrxAbPKEI",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="What can I order?",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jba4DMl6mmcQUHYwtdGSbk56fUF6 at 0x7f60ad30a170> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nMost sandwiches are $6.50. You can order a la cart"
#     }
#   ],
#   "created": 1646774568,
#   "id": "cmpl-4jba4DMl6mmcQUHYwtdGSbk56fUF6",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="Do you have any toppings?",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jbdQXGZtaHXFPI9egEVKZfQv2Btb at 0x7f60ad3dbad0> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n#3 Do you prefer pizza with vegetables?\n#4 What kind of"
#     }
#   ],
#   "created": 1646774776,
#   "id": "cmpl-4jbdQXGZtaHXFPI9egEVKZfQv2Btb",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="Can I have a black coffee, please?",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jbfe2VOGzxZVVLuNUO1TAOGwtPyG at 0x7f60ad3dbd10> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nYes, I'll have one as well.\n\nCan I get"
#     }
#   ],
#   "created": 1646774914,
#   "id": "cmpl-4jbfe2VOGzxZVVLuNUO1TAOGwtPyG",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="When can I get my order?",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jbjEPBseNPIPlAw6SYDIsbV0Gt1G at 0x7f60ad3db410> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n#2\n\nYou can get it as fast as possible!\n#"
#     }
#   ],
#   "created": 1646775136,
#   "id": "cmpl-4jbjEPBseNPIPlAw6SYDIsbV0Gt1G",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="Do you have any offers for today?",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jblH2TjAbyxdUmpFrEoHT6LZ41g9 at 0x7f60ad81f4d0> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n#u\n\nYes, I'm in Cape Town and am looking to"
#     }
#   ],
#   "created": 1646775263,
#   "id": "cmpl-4jblH2TjAbyxdUmpFrEoHT6LZ41g9",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="I want to order a pizza.",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jbmPAAvzB3QKU9EycRtpRhmBGB0k at 0x7f60ad81f230> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n#Person2\n\nPlease confirm your order\n#Person2\n\n"
#     }
#   ],
#   "created": 1646775333,
#   "id": "cmpl-4jbmPAAvzB3QKU9EycRtpRhmBGB0k",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="#Person1#: What would you like to drink? #Person2#: I feel like a cup of black tea.' #Person1#: Wouldn't you like something to eat? #Person2#: Ye ",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jbsI8R06e3egwbmcnqhIKyz55uQT at 0x7f60ad81de30> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\n###\n\n 2#: Yes, I'd like a little bit of"
#     }
#   ],
#   "created": 1646775698,
#   "id": "cmpl-4jbsI8R06e3egwbmcnqhIKyz55uQT",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="I want ",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jbwS6zEnRoJOgA6zj31WLahVS64h at 0x7f60ad81f530> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\n1#:to see a doctor\n\n2#:to go"
#     }
#   ],
#   "created": 1646775956,
#   "id": "cmpl-4jbwS6zEnRoJOgA6zj31WLahVS64h",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="I want to reserve ",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jbzDNseJogBnveWvcXRGQWLXV9uf at 0x7f60ad822830> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\n###\n\n 2I want to reserve\n\n###\n\n 2I want"
#     }
#   ],
#   "created": 1646776127,
#   "id": "cmpl-4jbzDNseJogBnveWvcXRGQWLXV9uf",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="How can I help you sir? I want to order a pizza, please. Sure, sir. What is ",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jc34xkAt4yTi5MY5O5xokqo7RSTL at 0x7f60ad81fc50> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\n sauce, cheese and toppings that you prefer ? 46569\n\n"
#     }
#   ],
#   "created": 1646776366,
#   "id": "cmpl-4jc34xkAt4yTi5MY5O5xokqo7RSTL",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="#Person1#:How can I help you sir? #Person2#:I want to order a pizza, please. #Person1#:Sure, sir. What is ",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jc4SMcc2dn2TqFaR7w2TLP3TrK7I at 0x7f60ad81f110> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\n###\n\n 1#:Sure, sir. What is your order number"
#     }
#   ],
#   "created": 1646776452,
#   "id": "cmpl-4jc4SMcc2dn2TqFaR7w2TLP3TrK7I",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="#Person1#:How can I help you sir? #Person2#:I want to pick my pizza, please. #Person1#:Sure, What is ",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jc8lNdcdZbLiJjDLW0Hmcb90SE5V at 0x7f60ad809590> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\n###\n\n 1#:Sure, What is your order number? #"
#     }
#   ],
#   "created": 1646776719,
#   "id": "cmpl-4jc8lNdcdZbLiJjDLW0Hmcb90SE5V",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="I want to book a table, please. sure, how many ",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jc9zQq0IemOjey4dwWaczZMscbyE at 0x7f60ad3db1d0> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nBook now, hold on, I'm looking for a table for four"
#     }
#   ],
#   "created": 1646776795,
#   "id": "cmpl-4jc9zQq0IemOjey4dwWaczZMscbyE",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="Can I take your order? I'd like to order a pizza. sure, Anything to drink?  I'd like ",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jcE5mb1dTxyIMOjtaEflBFjTJCdy at 0x7f60ad82b170> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\n###\n\n 1 I'd like a glass of riesling, please"
#     }
#   ],
#   "created": 1646777049,
#   "id": "cmpl-4jcE5mb1dTxyIMOjtaEflBFjTJCdy",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="Can I take your order? I'd like to order a lemonade juice. Anything to drink?",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jcCQ4acnd0Oa66u0I5gVlsKaRqPY at 0x7f60ad7fd6b0> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " \n\n\u2014 Yes, another lemonade. \n\nCan I get"
#     }
#   ],
#   "created": 1646776946,
#   "id": "cmpl-4jcCQ4acnd0Oa66u0I5gVlsKaRqPY",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
x = openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="Can I take your order? I'd like to order a lemonade juice. Anything to drink?",)

# %%
x["choices"][0]["text"]
# Out:
# '\n#259113\n\n风勤此道 Your order'

# %%
x
# Out:
# <OpenAIObject text_completion id=cmpl-4jcEsO3iCCqmEIGgNr36JZx4Z3TQT at 0x7f60ad82b650> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n#259113\n\n\u98ce\u52e4\u6b64\u9053 Your order"
#     }
#   ],
#   "created": 1646777098,
#   "id": "cmpl-4jcEsO3iCCqmEIGgNr36JZx4Z3TQT",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
x = openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="Can I take your order? I'd like to order a pizza. Anything to drink?",)
print(x)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n# \u00a0Yes, I'd like a coke\n# \n"
#     }
#   ],
#   "created": 1646777170,
#   "id": "cmpl-4jcG2fzBDKSOWHHTto0tjecG1p9f3",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }

# %%
openai.Completion.create(
    model="curie:ft-personal-2022-03-08-21-16-22",
    prompt="Can I take your order? I'd like to order a ",)
# Out:
# <OpenAIObject text_completion id=cmpl-4jcHtNq4dlckAqtViUzzBTXNM89gX at 0x7f60acd25710> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nCan I take your order? I'd like to order a bottled water"
#     }
#   ],
#   "created": 1646777285,
#   "id": "cmpl-4jcHtNq4dlckAqtViUzzBTXNM89gX",
#   "model": "curie:ft-personal-2022-03-08-21-16-22",
#   "object": "text_completion"
# }
